# %%
import pandas as pd

# %%
mvps=pd.read_csv(r"datasets/mvps.csv")

# %%
mvps=mvps[["Player", "Year", "Pts Won", "Pts Max", "Share"]]

# %%
mvps.head()
# Out:
#             Player  Year  Pts Won  Pts Max  Share
# 0   Michael Jordan  1991    891.0      960  0.928
# 1    Magic Johnson  1991    497.0      960  0.518
# 2   David Robinson  1991    476.0      960  0.496
# 3  Charles Barkley  1991    222.0      960  0.231
# 4      Karl Malone  1991    142.0      960  0.148

# %%
players=pd.read_csv(r'datasets\players.csv')
players
# Out:
#        Unnamed: 0   Rk              Player Pos Age   Tm   G  GS    MP   FG  \
# 0               0    1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3
# 1               1    2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2
# 2               2    3          Mark Acres   C  28  ORL  68   0  19.3  1.6
# 3               3    4       Michael Adams  PG  28  DEN  66  66  35.5  8.5
# 4               4    5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4
# ...           ...  ...                 ...  ..  ..  ...  ..  ..   ...  ...
# 18039         725  536        Delon Wright  PG  28  SAC  27   8  25.8  3.9
# 18040         726  537      Thaddeus Young  PF  32  CHI  68  23  24.3  5.4
# 18041         727  538          Trae Young  PG  22  ATL  63  63  33.7  7.7
# 18042         728  539         Cody Zeller   C  28  CHO  48  21  20.9  3.8
# 18043         729  540         Ivica Zubac   C  23  LAC  72  33  22.3  3.6
#
#        ...  ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0      ...  0.6  1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1      ...  0.5  1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2      ...  2.1  3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3      ...  0.9  3.0  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4      ...  1.7  3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
# ...    ...  ...  ...  ...   ...  ...  ...  ...  ...   ...   ...
# 18039  ...  1.0  2.9  3.9   3.6  1.6  0.4  1.3  1.1  10.0  2021
# 18040  ...  2.5  3.8  6.2   4.3  1.1  0.6  2.0  2.2  12.1  2021
# 18041  ...  0.6  3.3  3.9   9.4  0.8  0.2  4.1  1.8  25.3  2021
# 18042  ...  2.5  4.4  6.8   1.8  0.6  0.4  1.1  2.5   9.4  2021
# 18043  ...  2.6  4.6  7.2   1.3  0.3  0.9  1.1  2.6   9.0  2021
#
# [18044 rows x 32 columns]

# %%
del players['Unnamed: 0']
del players['Rk']

# %%
players.head()
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 0      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  .474  ...  0.6
# 1  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  .413  ...  0.5
# 2          Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  .509  ...  2.1
# 3       Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  .394  ...  0.9
# 4        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  .462  ...  1.7
#
#    DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0  1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1  1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2  3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3  3.0  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4  3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
#
# [5 rows x 30 columns]

# %%
players["Player"]=players["Player"].str.replace("*","",regex=False)
players.groupby(["Player","Year"]).get_group(("Greg Anderson", 1991))
# Out:
#            Player Pos Age   Tm   G GS    MP   FG  FGA    FG%  ...  ORB  DRB  \
# 8   Greg Anderson  PF  26  TOT  68  2  13.6  1.7  4.0   .430  ...  1.4  3.3
# 9   Greg Anderson  PF  26  MIL  26  0   9.5  1.0  2.8   .370  ...  1.0  1.9
# 10  Greg Anderson  PF  26  NJN   1  0  18.0  4.0  4.0  1.000  ...  4.0  2.0
# 11  Greg Anderson  PF  26  DEN  41  2  16.1  2.1  4.7   .440  ...  1.6  4.1
#
#     TRB  AST  STL  BLK  TOV   PF  PTS  Year
# 8   4.7  0.2  0.5  0.7  1.2  2.1  4.3  1991
# 9   2.9  0.1  0.3  0.3  0.8  1.1  2.7  1991
# 10  6.0  1.0  2.0  0.0  1.0  4.0  8.0  1991
# 11  5.8  0.3  0.6  0.9  1.5  2.6  5.2  1991
#
# [4 rows x 30 columns]

# %%
players.head(50)
players.shape
# Out:
# (18044, 30)

# %%
# def combine_players(df):
#     if df.shape[0] == 1:
#         return df
#     else:
#         row = df[df["Tm"] == "TOT"].copy()  # Use .copy() to avoid warnings
#         if not row.empty:
#             row["Tm"] = df.iloc[-1]["Tm"]  # Access the last row"s team
#             return row
#         else:
#             return df.iloc[-1:]  # Return the last row if "TOT" isn"t found
def combine_players(df):
    if df.shape[0] == 1:
        return df
    else:
        row = df[df["Tm"] == "TOT"].copy()
        row["Tm"] = df.iloc[-1,:]["Tm"]
        return row

players = players.groupby(["Player", "Year"]).apply(combine_players)
# Out:
# C:\Users\zac15\AppData\Local\Temp\ipykernel_10460\3410434338.py:19: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   players = players.groupby(["Player", "Year"]).apply(combine_players)

# %%
print(players.head(20))
# Out:
#                                  Player Pos Age   Tm   G  GS    MP   FG   FGA  \
# Player        Year
# A.C. Green    1991 164       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6
#               1992 633       A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8
#               1993 1092      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6
#               1994 1579      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3
#               1995 2067      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5
#               1996 2563      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4
#               1997 3138      A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8
#               1998 3725      A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5
#               1999 4283      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1
#               2000 4811      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7
#               2001 5330      A.C. Green  PF  37  MIA  82   1  17.2  1.8   4.0
# A.J. Bramlett 2000 4684   A.J. Bramlett   C  23  CLE   8   0   7.6  0.5   2.6
# A.J. English  1991 127     A.J. English  SG  23  WSB  70  12  20.6  3.6   8.2
#               1992 597     A.J. English  SG  24  WSB  81   6  20.6  4.5  10.4
# A.J. Guyton   2001 5333     A.J. Guyton  PG  22  CHI  33   8  19.1  2.4   5.8
#               2002 5886     A.J. Guyton  PG  23  CHI  45   6  13.5  2.0   5.4
#               2003 6393     A.J. Guyton  PG  24  GSW   2   0   4.5  0.0   2.0
# A.J. Hammons  2017 14814   A.J. Hammons   C  24  DAL  22   0   7.4  0.8   1.9
# A.J. Price    2010 10727     A.J. Price  PG  23  IND  56   2  15.4  2.6   6.3
#               2011 11356     A.J. Price  PG  24  IND  50   0  15.9  2.3   6.4
#
#                            FG%  ...  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  \
# Player        Year              ...
# A.C. Green    1991 164    .476  ...  2.5  3.8  6.3  0.9  0.7  0.3  1.2  1.4
#               1992 633    .476  ...  3.7  5.6  9.3  1.4  1.1  0.4  1.4  1.7
#               1993 1092   .537  ...  3.5  5.2  8.7  1.4  1.1  0.5  1.4  1.8
#               1994 1579   .502  ...  3.4  5.8  9.2  1.7  0.9  0.5  1.2  1.7
#               1995 2067   .504  ...  2.4  5.8  8.2  1.5  0.7  0.4  1.4  1.8
#               1996 2563   .484  ...  2.0  4.7  6.8  0.9  0.5  0.3  1.0  1.7
#               1997 3138   .483  ...  2.7  5.2  7.9  0.8  0.8  0.2  0.9  1.7
#               1998 3725   .453  ...  2.7  5.5  8.1  1.5  1.0  0.3  0.8  1.9
#               1999 4283   .422  ...  1.6  2.9  4.6  0.5  0.6  0.2  0.4  1.4
#               2000 4811   .447  ...  2.0  4.0  5.9  1.0  0.6  0.2  0.6  1.5
#               2001 5330   .444  ...  1.3  2.5  3.8  0.5  0.4  0.1  0.5  1.5
# A.J. Bramlett 2000 4684   .190  ...  1.5  1.3  2.8  0.0  0.1  0.0  0.4  1.6
# A.J. English  1991 127    .439  ...  0.9  1.2  2.1  2.5  0.4  0.2  1.6  1.8
#               1992 597    .433  ...  0.9  1.2  2.1  1.8  0.4  0.1  1.1  2.0
# A.J. Guyton   2001 5333   .406  ...  0.3  0.8  1.1  1.9  0.3  0.2  0.7  1.1
#               2002 5886   .361  ...  0.3  0.7  1.0  1.8  0.2  0.2  0.8  0.5
#               2003 6393   .000  ...  0.0  0.0  0.0  1.0  0.5  0.0  0.5  0.0
# A.J. Hammons  2017 14814  .405  ...  0.4  1.3  1.6  0.2  0.0  0.6  0.5  1.0
# A.J. Price    2010 10727  .410  ...  0.2  1.4  1.6  1.9  0.6  0.1  1.1  0.9
#               2011 11356  .356  ...  0.3  1.1  1.4  2.2  0.6  0.0  1.1  1.2
#
#                            PTS  Year
# Player        Year
# A.C. Green    1991 164     9.1  1991
#               1992 633    13.6  1992
#               1993 1092   12.8  1993
#               1994 1579   14.7  1994
#               1995 2067   11.2  1995
#               1996 2563    7.5  1996
#               1997 3138    7.2  1997
#               1998 3725    7.3  1998
#               1999 4283    4.9  1999
#               2000 4811    5.0  2000
#               2001 5330    4.5  2001
# A.J. Bramlett 2000 4684    1.0  2000
# A.J. English  1991 127     8.8  1991
#               1992 597    10.9  1992
# A.J. Guyton   2001 5333    6.0  2001
#               2002 5886    5.4  2002
#               2003 6393    0.0  2003
# A.J. Hammons  2017 14814   2.2  2017
# A.J. Price    2010 10727   7.3  2010
#               2011 11356   6.5  2011
#
# [20 rows x 30 columns]

# %%
players.index=players.index.droplevel()

# %%
players.index=players.index.droplevel()

# %%
players[players['Player']=='Greg Anderson']
# Out:
#              Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 8     Greg Anderson  PF  26  DEN  68   2  13.6  1.7   4.0  .430  ...  1.4
# 467   Greg Anderson  PF  27  DEN  82  82  34.1  4.7  10.4  .456  ...  4.1
# 1412  Greg Anderson  PF  29  DET  77  47  21.1  2.6   4.8  .543  ...  2.4
# 1911  Greg Anderson  PF  30  ATL  51   0  12.2  1.1   2.0  .548  ...  1.2
# 2381  Greg Anderson  PF  31  SAS  46   7   7.5  0.5   1.0  .511  ...  0.6
# 2948  Greg Anderson   C  32  SAS  82  48  20.2  1.6   3.2  .496  ...  1.9
# 3541  Greg Anderson   C  33  ATL  50   0   8.0  0.7   1.6  .444  ...  0.8
#
#       DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 8     3.3   4.7  0.2  0.5  0.7  1.2  2.1   4.3  1991
# 467   7.4  11.5  1.0  1.1  0.8  2.5  3.2  11.5  1992
# 1412  5.0   7.4  0.7  0.7  0.9  1.2  3.0   6.4  1994
# 1911  2.5   3.7  0.3  0.5  0.6  0.6  2.0   2.9  1995
# 2381  1.5   2.2  0.2  0.2  0.5  0.5  1.4   1.2  1996
# 2948  3.5   5.5  0.4  0.8  0.8  0.9  2.7   3.9  1997
# 3541  1.6   2.4  0.3  0.4  0.2  0.3  1.7   1.8  1998
#
# [7 rows x 30 columns]

# %%
mvps.shape
# Out:
# (474, 5)

# %%
all_players=players.merge(mvps, how="outer", on=["Player","Year"])
all_players.shape
# Out:
# (14092, 33)

# %%
all_players[["Pts Won", "Pts Max","Share"]] = all_players[["Pts Won","Pts Max","Share"]].fillna(0)

# %%
teams=pd.read_csv(r'datasets/teams.csv')
teams.head(35)
# Out:
#     Unnamed: 0                 W                 L              W/L%  \
# 0            0                56                26              .683
# 1            1                44                38              .537
# 2            2                39                43              .476
# 3            3                30                52              .366
# 4            4                26                56              .317
# 5            5                24                58              .293
# 6            6  Central Division  Central Division  Central Division
# 7            7                61                21              .744
# 8            8                50                32              .610
# 9            9                48                34              .585
# 10          10                43                39              .524
# 11          11                41                41              .500
# 12          12                33                49              .402
# 13          13                26                56              .317
# 14           0  Midwest Division  Midwest Division  Midwest Division
# 15           1                55                27              .671
# 16           2                54                28              .659
# 17           3                52                30              .634
# 18           4                31                51              .378
# 19           5                29                53              .354
# 20           6                28                54              .341
# 21           7                20                62              .244
# 22           8  Pacific Division  Pacific Division  Pacific Division
# 23           9                63                19              .768
# 24          10                58                24              .707
# 25          11                55                27              .671
# 26          12                44                38              .537
# 27          13                41                41              .500
# 28          14                31                51              .378
# 29          15                25                57              .305
# 30           0                51                31              .622
# 31           1                51                31              .622
# 32           2                40                42              .488
# 33           3                38                44              .463
# 34           4                35                47              .427
#
#                   GB              PS/G              PA/G               SRS  \
# 0                  —             111.5             105.7              5.22
# 1               12.0             105.4             105.6             -0.39
# 2               17.0             103.1             103.3             -0.43
# 3               26.0             101.4             106.4             -4.84
# 4               30.0             102.9             107.5             -4.53
# 5               32.0             101.8             107.8             -5.91
# 6   Central Division  Central Division  Central Division  Central Division
# 7                  —             110.0             101.0              8.57
# 8               11.0             100.1              96.8              3.08
# 9               13.0             106.4             104.0              2.33
# 10              18.0             109.8             109.0              0.72
# 11              20.0             111.7             112.1             -0.37
# 12              28.0             101.7             104.2             -2.33
# 13              35.0             102.8             108.0             -4.95
# 14  Midwest Division  Midwest Division  Midwest Division  Midwest Division
# 15                 —             107.1             102.6              4.30
# 16               1.0             104.0             100.7              3.18
# 17               3.0             106.7             103.2              3.27
# 18              24.0             105.9             109.9             -3.79
# 19              26.0              99.6             103.5             -3.75
# 20              27.0              99.9             104.5             -4.27
# 21              35.0             119.9             130.8            -10.31
# 22  Pacific Division  Pacific Division  Pacific Division  Pacific Division
# 23                 —             114.7             106.0              8.47
# 24               5.0             106.3              99.6              6.73
# 25               8.0             114.0             107.5              6.49
# 26              19.0             116.6             115.0              1.72
# 27              22.0             106.6             105.4              1.31
# 28              32.0             103.5             107.0             -3.16
# 29              38.0              96.7             103.5             -6.27
# 30                 —             106.6             103.0              3.41
# 31                 —             101.6              97.7              3.67
# 32              11.0             105.4             107.1             -1.54
# 33              13.0             105.0             109.2             -3.94
# 34              16.0             101.9             103.2             -1.34
#
#     Year                     Team
# 0   1991          Boston Celtics*
# 1   1991      Philadelphia 76ers*
# 2   1991         New York Knicks*
# 3   1991       Washington Bullets
# 4   1991          New Jersey Nets
# 5   1991               Miami Heat
# 6   1991         Central Division
# 7   1991           Chicago Bulls*
# 8   1991         Detroit Pistons*
# 9   1991         Milwaukee Bucks*
# 10  1991           Atlanta Hawks*
# 11  1991          Indiana Pacers*
# 12  1991      Cleveland Cavaliers
# 13  1991        Charlotte Hornets
# 14  1991         Midwest Division
# 15  1991       San Antonio Spurs*
# 16  1991               Utah Jazz*
# 17  1991         Houston Rockets*
# 18  1991            Orlando Magic
# 19  1991   Minnesota Timberwolves
# 20  1991         Dallas Mavericks
# 21  1991           Denver Nuggets
# 22  1991         Pacific Division
# 23  1991  Portland Trail Blazers*
# 24  1991      Los Angeles Lakers*
# 25  1991            Phoenix Suns*
# 26  1991   Golden State Warriors*
# 27  1991     Seattle SuperSonics*
# 28  1991     Los Angeles Clippers
# 29  1991         Sacramento Kings
# 30  1992          Boston Celtics*
# 31  1992         New York Knicks*
# 32  1992         New Jersey Nets*
# 33  1992              Miami Heat*
# 34  1992       Philadelphia 76ers

# %%
teams = teams[~teams["W"].str.contains("Division")].copy()
teams["Team"] = teams["Team"].str.replace("*", "", regex=False)
# del teams['Unnamed: 0']

# %%
nicknames={}

with open('abbrs.csv') as f:
    lines=f.readlines()
    for line in lines[1:]:
        abbr,full=line.replace("\n","").split(",")
        nicknames[abbr]=full

# %%
all_players["Team"]=all_players["Tm"].map(nicknames)
all_players.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
#        'Pts Won', 'Pts Max', 'Share', 'Team'],
#       dtype='object')

# %%
stats=all_players.merge(teams, how="outer",on=["Team", "Year"])

# %%
print(all_players.shape)
del stats["Unnamed: 0"]
print(stats.shape)
# Out:
# (14092, 34)
# (14092, 41)

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age         object
# Tm          object
# G           object
# GS          object
# MP          object
# FG          object
# FGA         object
# FG%         object
# 3P          object
# 3PA         object
# 3P%         object
# 2P          object
# 2PA         object
# 2P%         object
# eFG%        object
# FT          object
# FTA         object
# FT%         object
# ORB         object
# DRB         object
# TRB         object
# AST         object
# STL         object
# BLK         object
# TOV         object
# PF          object
# PTS         object
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W           object
# L           object
# W/L%        object
# GB          object
# PS/G        object
# PA/G        object
# SRS         object
# dtype: object

# %%
stats=stats.apply(pd.to_numeric, errors="ignore")
# Out:
# C:\Users\zac15\AppData\Local\Temp\ipykernel_10460\29912484.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   stats=stats.apply(pd.to_numeric, errors="ignore")

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB          object
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats["GB"].unique()
# Out:
# array(['18.0', '29.0', '14.0', '—', '10.0', '26.0', '13.0', '12.0', '2.0',
#        '28.0', '27.0', '17.0', '15.0', '33.0', '46.0', '6.0', '22.0',
#        '16.0', '20.0', '21.0', '25.0', '19.0', '3.0', '5.0', '11.0',
#        '23.0', '12.5', '9.0', '8.0', '4.0', '35.0', '31.0', '1.0', '41.0',
#        '24.0', '39.0', '45.0', '36.0', '7.0', '37.0', '38.0', '4.5',
#        '30.0', '43.0', '25.5', '44.0', '40.0', '42.0', '2.5', '51.0',
#        '34.0', '32.0', '20.5', '32.5', '48.0', '52.0', '3.5', '56.0',
#        '10.5', '47.0', '11.5', '22.5', '1.5', '50.0', '21.5', '18.5'],
#       dtype=object)

# %%
stats['GB']=stats['GB'].str.replace("—","0")
stats["GB"].unique()
stats["GB"]=pd.to_numeric(stats["GB"])

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB         float64
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats.to_csv(r"datasets/player_mvp_stats.csv",mode="w+")

# %%
scoring_leader=stats[stats["G"]>65].sort_values("PTS", ascending=False).head(10)
scoring_leader
# Out:
#                   Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 4914        James Harden  PG   29  HOU  78  78  36.8  10.8  24.5  0.442  ...
# 6151         Kobe Bryant  SG   27  LAL  80  80  41.0  12.2  27.2  0.450  ...
# 4931        James Harden  SG   30  HOU  68  68  36.5   9.9  22.3  0.444  ...
# 10222      Allen Iverson  PG   30  PHI  72  72  43.1  11.3  25.3  0.447  ...
# 1609      Michael Jordan  SG   29  CHI  78  78  39.3  12.7  25.7  0.495  ...
# 9708       Tracy McGrady  SG   23  ORL  75  74  39.4  11.1  24.2  0.457  ...
# 9385        Kevin Durant  SF   25  OKC  81  81  38.5  10.5  20.8  0.503  ...
# 9437   Russell Westbrook  PG   28  OKC  81  81  34.6  10.2  24.0  0.425  ...
# 6165         Kobe Bryant  SG   28  LAL  77  77  40.8  10.6  22.8  0.463  ...
# 1583      Michael Jordan  SG   27  CHI  82  82  37.0  12.1  22.4  0.539  ...
#
#        Pts Max  Share                   Team   W   L   W/L%    GB   PS/G  \
# 4914    1010.0  0.768        Houston Rockets  53  29  0.646   0.0  113.9
# 6151    1250.0  0.386     Los Angeles Lakers  45  37  0.549   9.0   99.4
# 4931    1010.0  0.363        Houston Rockets  44  28  0.611   0.0  117.8
# 10222   1250.0  0.001     Philadelphia 76ers  38  44  0.463  11.0   99.4
# 1609     980.0  0.577          Chicago Bulls  57  25  0.695   0.0  105.2
# 9708    1190.0  0.359          Orlando Magic  42  40  0.512   7.0   98.5
# 9385    1250.0  0.986  Oklahoma City Thunder  59  23  0.720   0.0  106.2
# 9437    1010.0  0.879  Oklahoma City Thunder  47  35  0.573   4.0  106.6
# 6165    1290.0  0.404     Los Angeles Lakers  42  40  0.512  19.0  103.3
# 1583     960.0  0.928          Chicago Bulls  61  21  0.744   0.0  110.0
#
#         PA/G   SRS
# 4914   109.1  4.96
# 6151    96.9  2.53
# 4931   114.8  3.13
# 10222  101.3 -2.10
# 1609    98.9  6.19
# 9708    98.4 -0.39
# 9385    99.8  6.66
# 9437   105.8  1.14
# 6165   103.4  0.24
# 1583   101.0  8.57
#
# [10 rows x 41 columns]

# %%
scoring_leader.plot.bar("Player","PTS")
# Out:
# <Axes: xlabel='Player'>

# %%
stats.groupby("Year").apply( lambda x: x.sort_values("PTS", ascending=False).head(1))
# Out:
# C:\Users\zac15\AppData\Local\Temp\ipykernel_10460\1367273205.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   stats.groupby("Year").apply( lambda x: x.sort_values("PTS", ascending=False).head(1))
#                        Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  \
# Year
# 1991 1583      Michael Jordan  SG   27  CHI  82  82  37.0  12.1  22.4  0.539
# 1992 1596      Michael Jordan  SG   28  CHI  80  80  38.8  11.8  22.7  0.519
# 1993 1609      Michael Jordan  SG   29  CHI  78  78  39.3  12.7  25.7  0.495
# 1994 11924     David Robinson   C   28  SAS  80  80  40.5  10.5  20.7  0.507
# 1995 9584    Shaquille O'Neal   C   22  ORL  79  79  37.0  11.8  20.2  0.583
# 1996 1656      Michael Jordan  SG   32  CHI  82  82  37.7  11.2  22.6  0.495
# 1997 1670      Michael Jordan  SG   33  CHI  82  82  37.9  11.2  23.1  0.486
# 1998 1684      Michael Jordan  SG   34  CHI  82  82  38.8  10.7  23.1  0.465
# 1999 10115      Allen Iverson  SG   23  PHI  48  48  41.5   9.1  22.0  0.412
# 2000 6068    Shaquille O'Neal   C   27  LAL  79  79  40.0  12.1  21.1  0.574
# 2001 10146      Allen Iverson  SG   25  PHI  71  71  42.0  10.7  25.5  0.420
# 2002 10162      Allen Iverson  SG   26  PHI  60  59  43.7  11.1  27.8  0.398
# 2003 9708       Tracy McGrady  SG   23  ORL  75  74  39.4  11.1  24.2  0.457
# 2004 9721       Tracy McGrady  SG   24  ORL  67  67  39.9   9.7  23.4  0.417
# 2005 10209      Allen Iverson  PG   29  PHI  75  75  42.3  10.3  24.2  0.424
# 2006 6151         Kobe Bryant  SG   27  LAL  80  80  41.0  12.2  27.2  0.450
# 2007 6165         Kobe Bryant  SG   28  LAL  77  77  40.8  10.6  22.8  0.463
# 2008 2319        LeBron James  SF   23  CLE  75  74  40.4  10.6  21.9  0.484
# 2009 7019         Dwyane Wade  SG   27  MIA  79  79  38.6  10.8  22.0  0.491
# 2010 9323        Kevin Durant  SF   21  OKC  82  82  39.5   9.7  20.3  0.476
# 2011 9339        Kevin Durant  SF   22  OKC  78  78  38.9   9.1  19.7  0.462
# 2012 9354        Kevin Durant  SF   23  OKC  66  66  38.6   9.7  19.7  0.496
# 2013 9152     Carmelo Anthony  PF   28  NYK  67  67  37.0  10.0  22.2  0.449
# 2014 9385        Kevin Durant  SF   25  OKC  81  81  38.5  10.5  20.8  0.503
# 2015 9408   Russell Westbrook  PG   26  OKC  67  67  34.4   9.4  22.0  0.426
# 2016 4389       Stephen Curry  PG   27  GSW  79  79  34.2  10.2  20.2  0.504
# 2017 9437   Russell Westbrook  PG   28  OKC  81  81  34.6  10.2  24.0  0.425
# 2018 4891        James Harden  SG   28  HOU  72  72  35.4   9.0  20.1  0.449
# 2019 4914        James Harden  PG   29  HOU  78  78  36.8  10.8  24.5  0.442
# 2020 4931        James Harden  SG   30  HOU  68  68  36.5   9.9  22.3  0.444
# 2021 4473       Stephen Curry  PG   32  GSW  63  63  34.2  10.4  21.7  0.482
#
#             ...  Pts Max  Share                   Team   W   L   W/L%    GB  \
# Year        ...
# 1991 1583   ...    960.0  0.928          Chicago Bulls  61  21  0.744   0.0
# 1992 1596   ...    960.0  0.938          Chicago Bulls  67  15  0.817   0.0
# 1993 1609   ...    980.0  0.577          Chicago Bulls  57  25  0.695   0.0
# 1994 11924  ...   1010.0  0.723      San Antonio Spurs  55  27  0.671   3.0
# 1995 9584   ...   1050.0  0.576          Orlando Magic  57  25  0.695   0.0
# 1996 1656   ...   1130.0  0.986          Chicago Bulls  72  10  0.878   0.0
# 1997 1670   ...   1150.0  0.832          Chicago Bulls  69  13  0.841   0.0
# 1998 1684   ...   1160.0  0.934          Chicago Bulls  62  20  0.756   0.0
# 1999 10115  ...   1180.0  0.270     Philadelphia 76ers  28  22  0.560   5.0
# 2000 6068   ...   1210.0  0.998     Los Angeles Lakers  67  15  0.817   0.0
# 2001 10146  ...   1240.0  0.904     Philadelphia 76ers  56  26  0.683   0.0
# 2002 10162  ...   1260.0  0.023     Philadelphia 76ers  43  39  0.524   9.0
# 2003 9708   ...   1190.0  0.359          Orlando Magic  42  40  0.512   7.0
# 2004 9721   ...      0.0  0.000          Orlando Magic  21  61  0.256  26.0
# 2005 10209  ...   1270.0  0.189     Philadelphia 76ers  43  39  0.524   2.0
# 2006 6151   ...   1250.0  0.386     Los Angeles Lakers  45  37  0.549   9.0
# 2007 6165   ...   1290.0  0.404     Los Angeles Lakers  42  40  0.512  19.0
# 2008 2319   ...   1260.0  0.348    Cleveland Cavaliers  45  37  0.549  14.0
# 2009 7019   ...   1210.0  0.562             Miami Heat  43  39  0.524  16.0
# 2010 9323   ...   1230.0  0.495  Oklahoma City Thunder  50  32  0.610   3.0
# 2011 9339   ...   1210.0  0.157  Oklahoma City Thunder  55  27  0.671   0.0
# 2012 9354   ...   1210.0  0.735  Oklahoma City Thunder  47  19  0.712   0.0
# 2013 9152   ...   1210.0  0.393        New York Knicks  54  28  0.659   0.0
# 2014 9385   ...   1250.0  0.986  Oklahoma City Thunder  59  23  0.720   0.0
# 2015 9408   ...   1300.0  0.271  Oklahoma City Thunder  45  37  0.549   6.0
# 2016 4389   ...   1310.0  1.000  Golden State Warriors  73   9  0.890   0.0
# 2017 9437   ...   1010.0  0.879  Oklahoma City Thunder  47  35  0.573   4.0
# 2018 4891   ...   1010.0  0.955        Houston Rockets  65  17  0.793   0.0
# 2019 4914   ...   1010.0  0.768        Houston Rockets  53  29  0.646   0.0
# 2020 4931   ...   1010.0  0.363        Houston Rockets  44  28  0.611   0.0
# 2021 4473   ...   1010.0  0.449  Golden State Warriors  39  33  0.542  12.0
#
#              PS/G   PA/G    SRS
# Year
# 1991 1583   110.0  101.0   8.57
# 1992 1596   109.9   99.5  10.07
# 1993 1609   105.2   98.9   6.19
# 1994 11924  100.0   94.8   5.05
# 1995 9584   110.9  103.8   6.44
# 1996 1656   105.2   92.9  11.80
# 1997 1670   103.1   92.3  10.70
# 1998 1684    96.7   89.6   7.24
# 1999 10115   89.7   87.6   2.56
# 2000 6068   100.8   92.3   8.41
# 2001 10146   94.7   90.4   3.64
# 2002 10162   91.0   89.4   1.27
# 2003 9708    98.5   98.4  -0.39
# 2004 9721    94.0  101.1  -7.25
# 2005 10209   99.1   99.9  -1.07
# 2006 6151    99.4   96.9   2.53
# 2007 6165   103.3  103.4   0.24
# 2008 2319    96.4   96.7  -0.53
# 2009 7019    98.3   98.0   0.49
# 2010 9323   101.5   98.0   3.55
# 2011 9339   104.8  101.0   3.81
# 2012 9354   103.1   96.9   6.44
# 2013 9152   100.0   95.7   3.73
# 2014 9385   106.2   99.8   6.66
# 2015 9408   104.0  101.8   2.47
# 2016 4389   114.9  104.1  10.38
# 2017 9437   106.6  105.8   1.14
# 2018 4891   112.4  103.9   8.21
# 2019 4914   113.9  109.1   4.96
# 2020 4931   117.8  114.8   3.13
# 2021 4473   113.7  112.7   1.10
#
# [31 rows x 41 columns]

# %%
stats.select_dtypes(include=[float, int]).corr()["Share"]
# Out:
# Age        0.018596
# G          0.089282
# GS         0.167476
# MP         0.162175
# FG         0.276365
# FGA        0.249254
# FG%        0.065789
# 3P         0.096225
# 3PA        0.096460
# 3P%        0.013611
# 2P         0.275976
# 2PA        0.251885
# 2P%        0.063240
# eFG%       0.059335
# FT         0.316392
# FTA        0.321457
# FT%        0.037875
# ORB        0.101375
# DRB        0.213241
# TRB        0.186209
# AST        0.200253
# STL        0.175041
# BLK        0.154713
# TOV        0.233015
# PF         0.071046
# PTS        0.288267
# Year      -0.008135
# Pts Won    0.995153
# Pts Max    0.521335
# Share      1.000000
# W          0.122718
# L         -0.121866
# W/L%       0.126559
# GB        -0.101014
# PS/G       0.045206
# PA/G      -0.039617
# SRS        0.122782
# Name: Share, dtype: float64

# %%
stats.select_dtypes(include=[float, int]).corr()["Share"].plot.bar()
# Out:
# <Axes: >

# %%
pd.isnull(stats).sum()
# Out:
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%          50
# 3P            0
# 3PA           0
# 3P%        2042
# 2P            0
# 2PA           0
# 2P%          84
# eFG%         50
# FT            0
# FTA           0
# FT%         462
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# Year          0
# Pts Won       0
# Pts Max       0
# Share         0
# Team          0
# W             0
# L             0
# W/L%          0
# GB            0
# PS/G          0
# PA/G          0
# SRS           0
# dtype: int64

# %%
stats=stats.fillna(0)
stats.to_csv(r"datasets/player_mvp_stats.csv")
